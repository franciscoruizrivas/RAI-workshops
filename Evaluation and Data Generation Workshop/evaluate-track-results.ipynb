# %% [markdown]
# ## Track Evaluation Results in Azure AI Studio
#
# Contoso Gameworks is developing an AI-powered dialogue generator for video game characters, customizing interactions based on game scenarios. The generator should be evaluated for relevance (fitting dialogue to the game's plot and character traits), fluency (smooth, immersive conversations), and risk and safety (ensuring no violent, offensive, or unfair language is introduced).
#
# In this exercise, you will run an evaluation to assess a dataset of character dialogue generated by the generator. You will push the results to your Azure AI project to track the results in Azure AI Foundry.

# %% [markdown]
# ## Add environment variables to the .env file
#
# In the root of the **Evaluation and Data Generation Workshop** folder is an `.env` file. Within the `.env` file, fill in the values for the environment variables. You can locate the values for each environment variable in the following locations of the [Azure AI Foundry](https://ai.azure.com) portal:
#
# - `AZURE_SUBSCRIPTION_ID` - On the **Overview** page of your project within **Project details**.
# - `AZURE_AI_PROJECT_NAME` - At the top of the **Overview** page for your project.
# - `AZURE_OPENAI_RESOURCE_GROUP` - On the **Overview** page of the **Management Center** within **Project properties**.
# - `AZURE_OPENAI_SERVICE` - On the **Overview** page of your project in the **Included capabilities** tab for **Azure OpenAI Service**.
# - `AZURE_OPENAI_API_VERSION` - On the [API version lifecycle](https://learn.microsoft.com/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release) webpage within the **Latest GA API release** section.
# - `AZURE_OPENAI_ENDPOINT` - On the **Details** tab of your model deployment within **Endpoint** (i.e. **Target URI**)
# - `AZURE_OPENAI_DEPLOYMENT_NAME` -  On the **Details** tab of your model deployment within **Deployment info**.

# %% [markdown]
# # Sign in to Azure
#
# As a security best practice, we'll use [keyless authentication](https://learn.microsoft.com/azure/developer/ai/keyless-connections?tabs=csharp%2Cazure-cli) to authenticate to Azure OpenAI with Microsoft Entra ID. Before you can do so, you'll first need to install the **Azure CLI** per the [installation instructions](https://learn.microsoft.com/cli/azure/install-azure-cli) for your operating system.
#
# Next, open a terminal and run `az login` to sign in to your Azure account.

# %% [markdown]
# ## Sign-in to Azure
#
# To track the evaluation results in Azure AI Studio, you'll need to first login with your Azure AI account used to provision the Azure resources.
#
# Open a new terminal and enter the following command and follow the instruction in the terminal:
#
# `az login --use-device-code`
#
# Once you've logged in, select your subscription in the terminal.

# %% [markdown]
# ## Retrieve your values for assigning the Storage Blob Data Contributor role
#
# You'll need the following information to later assign yourself the **Storage Blog Data Contributor** role, which provides access to the Azure AI Project storage account. This permission is necessary for pushing the results to your Azure AI project.
#
# **Resource Group and Subscription ID**
#
# Each value can be found within the **Management center** for your project, located in [Azure AI Foundry](https://ai.azure.com). The **Management center** page is accessible via the left navigation menu of your project (at the very bottom of the navigation menu).
#
# **User ID**
#
# Enter the following command into the terminal:
#
# `az ad signed-in-user show --query id --output tsv`

# %% [markdown]
# ## Assign yourself the Storage Blob Data Contributor role
#
# In the terminal, enter the following command, replacing the placeholder text with your **subscription ID**, **resource group**, and **user ID**.
#
# `az role assignment create --role "Storage Blob Data Contributor" --scope /subscriptions/<mySubscriptionID>/resourceGroups/<myResourceGroupName> --assignee-principal-type User --assignee-object-id "<user-id>"`

# %% [markdown]
# ## Install the package
#
# The evaluator classes as well as the `evaluate` function are available in the Azure AI Evaluation SDK. In addition, we'll need to use `promptflow[azure]` to track the results in our Azure AI project. We'll begin by installing all the required packages.

# %%
# %pip install promptflow-azure azure-ai-evaluation
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: promptflow-azure in /home/vscode/.local/lib/python3.11/site-packages (1.18.1)
# Requirement already satisfied: azure-ai-evaluation in /home/vscode/.local/lib/python3.11/site-packages (1.9.0)
# Requirement already satisfied: azure-ai-ml<2.0.0,>=1.14.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure) (1.27.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.26.4 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure) (1.35.0)
# Requirement already satisfied: azure-cosmos<5.0.0,>=4.5.1 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure) (4.9.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.12.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure) (1.23.0)
# Requirement already satisfied: azure-storage-blob<13.0.0,>=12.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-storage-blob[aio]<13.0.0,>=12.17.0->promptflow-azure) (12.25.1)
# Requirement already satisfied: promptflow-devkit<2.0.0,>=1.18.1 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure) (1.18.1)
# Requirement already satisfied: pyjwt<3.0.0,>=2.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-azure) (2.10.1)
# Requirement already satisfied: promptflow-core>=1.17.1 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (1.18.1)
# Requirement already satisfied: nltk>=3.9.1 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: httpx>=0.25.1 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: pandas<3.0.0,>=2.1.2 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (2.3.0)
# Requirement already satisfied: openai>=1.78.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (1.93.0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (0.18.14)
# Requirement already satisfied: msrest>=0.6.21 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: Jinja2>=3.1.6 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (3.1.6)
# Requirement already satisfied: aiohttp>=3.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-evaluation) (3.12.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.11/site-packages (from aiohttp>=3.0->azure-ai-evaluation) (1.20.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (6.0.2)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.6.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.26.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.24.0)
# Requirement already satisfied: tqdm<5.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.67.1)
# Requirement already satisfied: strictyaml<2.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.7.3)
# Requirement already satisfied: colorama<1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.4.6)
# Requirement already satisfied: azure-storage-file-share in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.21.0)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (12.20.0)
# Requirement already satisfied: pydash<9.0.0,>=6.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (7.0.7)
# Requirement already satisfied: isodate<1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.1.28)
# Requirement already satisfied: typing-extensions<5.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (4.14.0)
# Requirement already satisfied: azure-monitor-opentelemetry in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.6.7)
# Requirement already satisfied: six>=1.11.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.17.0)
# Requirement already satisfied: requests>=2.21.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.32.4)
# Requirement already satisfied: cryptography>=2.5 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (45.0.5)
# Requirement already satisfied: msal>=1.30.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.3.1)
# Requirement already satisfied: anyio in /home/vscode/.local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (4.9.0)
# Requirement already satisfied: certifi in /home/vscode/.local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/vscode/.local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (1.0.9)
# Requirement already satisfied: idna in /home/vscode/.local/lib/python3.11/site-packages (from httpx>=0.25.1->azure-ai-evaluation) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/vscode/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.1->azure-ai-evaluation) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.11/site-packages (from Jinja2>=3.1.6->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/vscode/.local/lib/python3.11/site-packages (from msrest>=0.6.21->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: click in /home/vscode/.local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.2.1)
# Requirement already satisfied: joblib in /home/vscode/.local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/vscode/.local/lib/python3.11/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.11.6)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.78.0->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.78.0->azure-ai-evaluation) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.78.0->azure-ai-evaluation) (2.11.7)
# Requirement already satisfied: sniffio in /home/vscode/.local/lib/python3.11/site-packages (from openai>=1.78.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: numpy>=1.23.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.11/site-packages (from pandas<3.0.0,>=2.1.2->azure-ai-evaluation) (2025.2)
# Requirement already satisfied: docstring_parser in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.115.14)
# Requirement already satisfied: filetype>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.1)
# Requirement already satisfied: promptflow-tracing==1.18.1 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (1.18.1)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (7.0.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-tracing==1.18.1->promptflow-core>=1.17.1->azure-ai-evaluation) (1.34.1)
# Requirement already satisfied: tiktoken>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-tracing==1.18.1->promptflow-core>=1.17.1->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: argcomplete>=3.2.3 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.6.2)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.0.0b39)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.18.0)
# Requirement already satisfied: flask-cors<7.0.0,>=6.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (6.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /usr/local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.1.41)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (24.3.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.34.1)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (11.0.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.1.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (2.0.41)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.0.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/vscode/.local/lib/python3.11/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->azure-ai-evaluation) (0.2.12)
# Requirement already satisfied: fixedint==0.1.6 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.1.6)
# Requirement already satisfied: opentelemetry-api~=1.26 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.34.1)
# Requirement already satisfied: cffi>=1.14 in /home/vscode/.local/lib/python3.11/site-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (1.17.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/vscode/.local/lib/python3.11/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.46.2)
# Requirement already satisfied: blinker>=1.9.0 in /home/vscode/.local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.3)
# Requirement already satisfied: aniso8601>=0.82 in /home/vscode/.local/lib/python3.11/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.0.1)
# Requirement already satisfied: importlib-resources in /home/vscode/.local/lib/python3.11/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (6.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (4.0.12)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vscode/.local/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.26.0)
# Requirement already satisfied: jaraco.classes in /home/vscode/.local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /home/vscode/.local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (8.7.0)
# Requirement already satisfied: SecretStorage>=3.2 in /home/vscode/.local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.3.3)
# Requirement already satisfied: jeepney>=0.4.2 in /home/vscode/.local/lib/python3.11/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (0.9.0)
# Requirement already satisfied: packaging>=17.0 in /home/vscode/.local/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.5->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (25.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (1.34.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (5.29.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/vscode/.local/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai>=1.78.0->azure-ai-evaluation) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.26.4->promptflow-azure) (2.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-evaluation) (3.3.1)
# Requirement already satisfied: greenlet>=1 in /home/vscode/.local/lib/python3.11/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.2.3)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.0.0b12)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.53b0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.53b0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.53b0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.53b0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.53b0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.53b0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.53b0 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.4 in /home/vscode/.local/lib/python3.11/site-packages (from azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.1.5)
# Requirement already satisfied: pycparser in /home/vscode/.local/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity<2.0.0,>=1.12.0->promptflow-azure) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (5.0.2)
# Requirement already satisfied: zipp>=3.20 in /home/vscode/.local/lib/python3.11/site-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.55b1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-django~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (1.17.2)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: asgiref~=3.0 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (3.9.0)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.55b1 in /home/vscode/.local/lib/python3.11/site-packages (from opentelemetry-instrumentation-psycopg2~=0.53b0->azure-monitor-opentelemetry->azure-ai-ml<2.0.0,>=1.14.0->promptflow-azure) (0.55b1)
# Requirement already satisfied: more-itertools in /home/vscode/.local/lib/python3.11/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit<2.0.0,>=1.18.1->promptflow-azure) (10.7.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Access the environment variables.
#
# We'll import `os` and `load_dotenv` so that you can access the environment variables.

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Import packages
#
# We'll `json` to later dump the results into a new file. We'll also need `Path` to access the dataset. And finally, we'll need to import `evaluate` and the evaluators that we'll later use for evaluation.

# %%
import json
from pathlib import Path
from azure.ai.evaluation import evaluate, RelevanceEvaluator, FluencyEvaluator, ViolenceEvaluator, HateUnfairnessEvaluator, SexualEvaluator, SelfHarmEvaluator
# Out:
# [INFO] Could not import AIAgentConverter. Please install the dependency with `pip install azure-ai-projects`.
# [INFO] Could not import SKAgentConverter. Please install the dependency with `pip install semantic-kernel`.

# %% [markdown]
# ## Setup keyless authentication
#
# Rather than hardcode your **key**, we'll use a keyless connection with Azure OpenAI.

# %%
import azure.identity

credential = azure.identity.DefaultAzureCredential()
token_provider = azure.identity.get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")

token = token_provider()

# %% [markdown]
# ## Configure the model_config
#
# The `model_config` is necessary as it's a required parameter when creating an instance of an evaluator class. Let's configure the `model_config` with the following:
#
# - Azure OpenAI endpoint
# - Azure OpenAI API key

# %%
model_config = {
    "azure_endpoint": os.environ.get("AZURE_OPENAI_ENDPOINT"),
    "api_key": token,
    "azure_deployment": os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME")
}

# %% [markdown]
# ## Configure the Azure AI project
#
# The `azure_ai_project` is later passed into the `ContentSafetyEvaluator` to create an instance of the evaluator class. Let's configure the `azure_ai_project`.

# %%
azure_ai_project = {
    "project_name": os.environ.get("AZURE_AI_PROJECT_NAME"),
    "resource_group_name": os.environ.get("AZURE_OPENAI_RESOURCE_GROUP"),
    "subscription_id": os.environ.get("AZURE_SUBSCRIPTION_ID"),
    "api_key": token,
    "api_version": os.environ.get("AZURE_OPENAI_API_VERSION")
}

# %% [markdown]
# ## Set the path of the dataset
#
# We'll now set the path of the dataset that we'll use for the evalutation. The dataset is within the `gameworks-dialog.jsonl` file and consists of the following values for each row of data:
#
# - query
# - response
# - context

# %%
path = "gameworks-dialog.jsonl"

# %% [markdown]
# ## Create an instance of the evaluators
#
# Let's now create an instance of the **Relevance**, **Fluency** and **Content Safety** evaluators. The **Content Safety** evaluator is a composite evaluator which combines the following evaluators:
#
# - `ViolenceEvaluator`
# - `SexualEvaluator`
# - `SelfHarmEvaluator`
# - `HateUnfairnessEvaluator`

# %%
relevance_eval = RelevanceEvaluator(model_config)
fluency_eval = FluencyEvaluator(model_config)
violence_eval = ViolenceEvaluator(azure_ai_project=azure_ai_project, credential=credential)
hateunfairness_eval = HateUnfairnessEvaluator(azure_ai_project=azure_ai_project, credential=credential)
sexual_eval = SexualEvaluator(azure_ai_project=azure_ai_project, credential=credential)
selfharm_eval = SelfHarmEvaluator(azure_ai_project=azure_ai_project, credential=credential)
# Out:
# Class ViolenceEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class HateUnfairnessEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SexualEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.
# Class SelfHarmEvaluator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %% [markdown]
# ## Create the call to evaluate the dataset
#
# We can run an evaluation for a dataset with the `evaluate` function and include our list of evaluators. We must also ensure that the `evaluator_config` is set with the appropriate parameters and values for the `query`, `response`, `context` and `ground_truth`.
#
# Since we want to track the evaluation results in our Azure AI project, we'll need to include the Azure AI Foundry project information.

# %%
result = evaluate(
    data=path,
    evaluators={
        "relevance": relevance_eval,
        "fluency": fluency_eval,
        "violence": violence_eval,
        "hate_unfairness": hateunfairness_eval,
        "sexual": sexual_eval,
        "self_harm": selfharm_eval
    },
    # column mapping
    evaluator_config={
        "default": {
            "query": "${data.query}",
            "response": "${data.response}",
            "context": "${data.context}",
            "ground_truth": "${data.ground_truth}"
        }
    },
    azure_ai_project = azure_ai_project
)
# Out:
# [2025-07-03 16:17:14 +0000][promptflow][WARNING] - Found existing /workspaces/RAI-workshops/Evaluation and Data Generation Workshop/flow.flex.yaml, will not respect it in runtime.
# [2025-07-03 16:17:14 +0000][promptflow][WARNING] - Found existing /workspaces/RAI-workshops/Evaluation and Data Generation Workshop/flow.flex.yaml, will not respect it in runtime.
# [2025-07-03 16:17:14 +0000][promptflow][WARNING] - Found existing /workspaces/RAI-workshops/Evaluation and Data Generation Workshop/flow.flex.yaml, will not respect it in runtime.
# [2025-07-03 16:17:14 +0000][promptflow][WARNING] - Found existing /workspaces/RAI-workshops/Evaluation and Data Generation Workshop/flow.flex.yaml, will not respect it in runtime.
# [2025-07-03 16:17:14 +0000][promptflow][WARNING] - Found existing /workspaces/RAI-workshops/Evaluation and Data Generation Workshop/flow.flex.yaml, will not respect it in runtime.
# [2025-07-03 16:17:14 +0000][promptflow][WARNING] - Found existing /workspaces/RAI-workshops/Evaluation and Data Generation Workshop/flow.flex.yaml, will not respect it in runtime.
# [2025-07-03 16:17:14 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-07-03 16:17:14 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-07-03 16:17:14 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_violence_20250703_161714_128951, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_violence_20250703_161714_128951/logs.txt
# [2025-07-03 16:17:14 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-07-03 16:17:14 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-07-03 16:17:14 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_relevance_20250703_161714_128317, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250703_161714_128317/logs.txt
# [2025-07-03 16:17:14 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_self_harm_20250703_161714_132366, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_self_harm_20250703_161714_132366/logs.txt
# [2025-07-03 16:17:14 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-07-03 16:17:14 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_hate_unfairness_20250703_161714_129232, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_hate_unfairness_20250703_161714_129232/logs.txt
# [2025-07-03 16:17:14 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_fluency_20250703_161714_128680, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250703_161714_128680/logs.txt
# [2025-07-03 16:17:14 +0000][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-07-03 16:17:14 +0000][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_sexual_20250703_161714_129925, log path: /home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_sexual_20250703_161714_129925/logs.txt
# 2025-07-03 16:17:14 +0000   14353 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-07-03 16:17:16 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:16 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 2.51 seconds. Estimated time for incomplete lines: 5.02 seconds.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 1.34 seconds. Estimated time for incomplete lines: 1.34 seconds.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 0.9 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_relevance_20250703_161714_128317"
# Run status: "Completed"
# Start time: "2025-07-03 16:17:14.143991+00:00"
# Duration: "0:00:03.320797"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250703_161714_128317"
#
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 1.01 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-07-03 16:17:14 +0000   14353 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-07-03 16:17:16 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:16 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 2.46 seconds. Estimated time for incomplete lines: 4.92 seconds.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 1.32 seconds. Estimated time for incomplete lines: 1.32 seconds.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:17 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 1.01 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_fluency_20250703_161714_128680"
# Run status: "Completed"
# Start time: "2025-07-03 16:17:14.144539+00:00"
# Duration: "0:00:04.333332"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250703_161714_128680"
#
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.76 seconds. Estimated time for incomplete lines: 11.52 seconds.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.99 seconds. Estimated time for incomplete lines: 11.98 seconds.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 3.12 seconds. Estimated time for incomplete lines: 3.12 seconds.
# 2025-07-03 16:17:21 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:21 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 6.54 seconds. Estimated time for incomplete lines: 13.08 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.27 seconds. Estimated time for incomplete lines: 5.27 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.52 seconds. Estimated time for incomplete lines: 5.52 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 3.72 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 3.81 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-07-03 16:17:26 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:26 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 12.0 seconds. Estimated time for incomplete lines: 24.0 seconds.
# 2025-07-03 16:17:14 +0000   14353 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-07-03 16:17:21 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:21 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 6.54 seconds. Estimated time for incomplete lines: 13.08 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.27 seconds. Estimated time for incomplete lines: 5.27 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 3.81 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_self_harm_20250703_161714_132366"
# Run status: "Completed"
# Start time: "2025-07-03 16:17:14.149706+00:00"
# Duration: "0:00:12.388785"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_self_harm_20250703_161714_132366"
#
# 2025-07-03 16:17:14 +0000   14353 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.99 seconds. Estimated time for incomplete lines: 11.98 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.52 seconds. Estimated time for incomplete lines: 5.52 seconds.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:25 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 3.72 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_hate_unfairness_20250703_161714_129232"
# Run status: "Completed"
# Start time: "2025-07-03 16:17:14.146494+00:00"
# Duration: "0:00:12.381225"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_hate_unfairness_20250703_161714_129232"
#
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 6.7 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 10.11 seconds. Estimated time for incomplete lines: 10.11 seconds.
# 2025-07-03 16:17:14 +0000   14353 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 5.76 seconds. Estimated time for incomplete lines: 11.52 seconds.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:20 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 3.12 seconds. Estimated time for incomplete lines: 3.12 seconds.
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 6.7 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_violence_20250703_161714_128951"
# Run status: "Completed"
# Start time: "2025-07-03 16:17:14.145051+00:00"
# Duration: "0:00:21.379283"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_violence_20250703_161714_128951"
#
# 2025-07-03 16:17:36 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:36 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 7.45 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-07-03 16:17:14 +0000   14353 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-07-03 16:17:26 +0000   14353 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-07-03 16:17:26 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 12.0 seconds. Estimated time for incomplete lines: 24.0 seconds.
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Finished 2 / 3 lines.
# 2025-07-03 16:17:34 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 10.11 seconds. Estimated time for incomplete lines: 10.11 seconds.
# 2025-07-03 16:17:36 +0000   14353 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-07-03 16:17:36 +0000   14353 execution.bulk     INFO     Average execution time for completed lines: 7.45 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_sexual_20250703_161714_129925"
# Run status: "Completed"
# Start time: "2025-07-03 16:17:14.145733+00:00"
# Duration: "0:00:23.360122"
# Output path: "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_sexual_20250703_161714_129925"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "relevance": {
#         "status": "Completed",
#         "duration": "0:00:03.320797",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_relevance_20250703_161714_128317"
#     },
#     "fluency": {
#         "status": "Completed",
#         "duration": "0:00:04.333332",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_fluency_20250703_161714_128680"
#     },
#     "violence": {
#         "status": "Completed",
#         "duration": "0:00:21.379283",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_violence_20250703_161714_128951"
#     },
#     "hate_unfairness": {
#         "status": "Completed",
#         "duration": "0:00:12.381225",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_hate_unfairness_20250703_161714_129232"
#     },
#     "sexual": {
#         "status": "Completed",
#         "duration": "0:00:23.360122",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_sexual_20250703_161714_129925"
#     },
#     "self_harm": {
#         "status": "Completed",
#         "duration": "0:00:12.388785",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "/home/vscode/.promptflow/.runs/azure_ai_evaluation_evaluators_self_harm_20250703_161714_132366"
#     }
# }
#
# ====================================================
# https://ai.azure.com/build/evaluation/db9a1994-de7c-43c6-b997-ec3f02063b31?wsid=/subscriptions/973bd745-2c33-42c1-9ec6-b11a0a7f4aba/resourceGroups/rg-franciscoruizrivas-8637_ai/providers/Microsoft.MachineLearningServices/workspaces/franciscoruizrivas-4283
# [{"name": "FluencyEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "HateUnfairnessEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "Path", "type": "type", "fullType": "type"}, {"name": "RelevanceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SelfHarmEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SexualEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "ViolenceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "azure", "type": "module", "fullType": "module"}, {"name": "azure_ai_project", "type": "dict", "fullType": "dict"}, {"name": "credential", "type": "DefaultAzureCredential", "fullType": "azure.identity._credentials.default.DefaultAzureCredential"}, {"name": "evaluate", "type": "function", "fullType": "function"}, {"name": "fluency_eval", "type": "FluencyEvaluator", "fullType": "azure.ai.evaluation._evaluators._fluency._fluency.FluencyEvaluator"}, {"name": "hateunfairness_eval", "type": "HateUnfairnessEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._hate_unfairness.HateUnfairnessEvaluator"}, {"name": "json", "type": "module", "fullType": "module"}, {"name": "load_dotenv", "type": "function", "fullType": "function"}, {"name": "model_config", "type": "dict", "fullType": "dict"}, {"name": "os", "type": "module", "fullType": "module"}, {"name": "path", "type": "str", "fullType": "str"}, {"name": "relevance_eval", "type": "RelevanceEvaluator", "fullType": "azure.ai.evaluation._evaluators._relevance._relevance.RelevanceEvaluator"}, {"name": "result", "type": "dict", "fullType": "dict"}, {"name": "selfharm_eval", "type": "SelfHarmEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._self_harm.SelfHarmEvaluator"}, {"name": "sexual_eval", "type": "SexualEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._sexual.SexualEvaluator"}, {"name": "token", "type": "str", "fullType": "str"}, {"name": "token_provider", "type": "function", "fullType": "function"}, {"name": "violence_eval", "type": "ViolenceEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._violence.ViolenceEvaluator"}]
# [{"name": "FluencyEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "HateUnfairnessEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "Path", "type": "type", "fullType": "type"}, {"name": "RelevanceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SelfHarmEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SexualEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "ViolenceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "azure", "type": "module", "fullType": "module"}, {"name": "azure_ai_project", "type": "dict", "fullType": "dict"}, {"name": "credential", "type": "DefaultAzureCredential", "fullType": "azure.identity._credentials.default.DefaultAzureCredential"}, {"name": "evaluate", "type": "function", "fullType": "function"}, {"name": "fluency_eval", "type": "FluencyEvaluator", "fullType": "azure.ai.evaluation._evaluators._fluency._fluency.FluencyEvaluator"}, {"name": "hateunfairness_eval", "type": "HateUnfairnessEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._hate_unfairness.HateUnfairnessEvaluator"}, {"name": "json", "type": "module", "fullType": "module"}, {"name": "load_dotenv", "type": "function", "fullType": "function"}, {"name": "model_config", "type": "dict", "fullType": "dict"}, {"name": "os", "type": "module", "fullType": "module"}, {"name": "path", "type": "str", "fullType": "str"}, {"name": "relevance_eval", "type": "RelevanceEvaluator", "fullType": "azure.ai.evaluation._evaluators._relevance._relevance.RelevanceEvaluator"}, {"name": "result", "type": "dict", "fullType": "dict"}, {"name": "selfharm_eval", "type": "SelfHarmEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._self_harm.SelfHarmEvaluator"}, {"name": "sexual_eval", "type": "SexualEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._sexual.SexualEvaluator"}, {"name": "token", "type": "str", "fullType": "str"}, {"name": "token_provider", "type": "function", "fullType": "function"}, {"name": "violence_eval", "type": "ViolenceEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._violence.ViolenceEvaluator"}]
# [{"name": "FluencyEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "HateUnfairnessEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "Path", "type": "type", "fullType": "type"}, {"name": "RelevanceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SelfHarmEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SexualEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "ViolenceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "azure", "type": "module", "fullType": "module"}, {"name": "azure_ai_project", "type": "dict", "fullType": "dict"}, {"name": "credential", "type": "DefaultAzureCredential", "fullType": "azure.identity._credentials.default.DefaultAzureCredential"}, {"name": "evaluate", "type": "function", "fullType": "function"}, {"name": "fluency_eval", "type": "FluencyEvaluator", "fullType": "azure.ai.evaluation._evaluators._fluency._fluency.FluencyEvaluator"}, {"name": "hateunfairness_eval", "type": "HateUnfairnessEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._hate_unfairness.HateUnfairnessEvaluator"}, {"name": "json", "type": "module", "fullType": "module"}, {"name": "load_dotenv", "type": "function", "fullType": "function"}, {"name": "model_config", "type": "dict", "fullType": "dict"}, {"name": "os", "type": "module", "fullType": "module"}, {"name": "path", "type": "str", "fullType": "str"}, {"name": "relevance_eval", "type": "RelevanceEvaluator", "fullType": "azure.ai.evaluation._evaluators._relevance._relevance.RelevanceEvaluator"}, {"name": "result", "type": "dict", "fullType": "dict"}, {"name": "selfharm_eval", "type": "SelfHarmEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._self_harm.SelfHarmEvaluator"}, {"name": "sexual_eval", "type": "SexualEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._sexual.SexualEvaluator"}, {"name": "token", "type": "str", "fullType": "str"}, {"name": "token_provider", "type": "function", "fullType": "function"}, {"name": "violence_eval", "type": "ViolenceEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._violence.ViolenceEvaluator"}]
# [{"name": "FluencyEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "HateUnfairnessEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "Path", "type": "type", "fullType": "type"}, {"name": "RelevanceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SelfHarmEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SexualEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "ViolenceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "azure", "type": "module", "fullType": "module"}, {"name": "azure_ai_project", "type": "dict", "fullType": "dict"}, {"name": "credential", "type": "DefaultAzureCredential", "fullType": "azure.identity._credentials.default.DefaultAzureCredential"}, {"name": "evaluate", "type": "function", "fullType": "function"}, {"name": "fluency_eval", "type": "FluencyEvaluator", "fullType": "azure.ai.evaluation._evaluators._fluency._fluency.FluencyEvaluator"}, {"name": "hateunfairness_eval", "type": "HateUnfairnessEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._hate_unfairness.HateUnfairnessEvaluator"}, {"name": "json", "type": "module", "fullType": "module"}, {"name": "load_dotenv", "type": "function", "fullType": "function"}, {"name": "model_config", "type": "dict", "fullType": "dict"}, {"name": "os", "type": "module", "fullType": "module"}, {"name": "path", "type": "str", "fullType": "str"}, {"name": "relevance_eval", "type": "RelevanceEvaluator", "fullType": "azure.ai.evaluation._evaluators._relevance._relevance.RelevanceEvaluator"}, {"name": "result", "type": "dict", "fullType": "dict"}, {"name": "selfharm_eval", "type": "SelfHarmEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._self_harm.SelfHarmEvaluator"}, {"name": "sexual_eval", "type": "SexualEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._sexual.SexualEvaluator"}, {"name": "token", "type": "str", "fullType": "str"}, {"name": "token_provider", "type": "function", "fullType": "function"}, {"name": "violence_eval", "type": "ViolenceEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._violence.ViolenceEvaluator"}]
# [{"name": "FluencyEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "HateUnfairnessEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "Path", "type": "type", "fullType": "type"}, {"name": "RelevanceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SelfHarmEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "SexualEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "ViolenceEvaluator", "type": "ABCMeta", "fullType": "abc.ABCMeta"}, {"name": "azure", "type": "module", "fullType": "module"}, {"name": "azure_ai_project", "type": "dict", "fullType": "dict"}, {"name": "credential", "type": "DefaultAzureCredential", "fullType": "azure.identity._credentials.default.DefaultAzureCredential"}, {"name": "evaluate", "type": "function", "fullType": "function"}, {"name": "fluency_eval", "type": "FluencyEvaluator", "fullType": "azure.ai.evaluation._evaluators._fluency._fluency.FluencyEvaluator"}, {"name": "hateunfairness_eval", "type": "HateUnfairnessEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._hate_unfairness.HateUnfairnessEvaluator"}, {"name": "json", "type": "module", "fullType": "module"}, {"name": "load_dotenv", "type": "function", "fullType": "function"}, {"name": "model_config", "type": "dict", "fullType": "dict"}, {"name": "os", "type": "module", "fullType": "module"}, {"name": "path", "type": "str", "fullType": "str"}, {"name": "relevance_eval", "type": "RelevanceEvaluator", "fullType": "azure.ai.evaluation._evaluators._relevance._relevance.RelevanceEvaluator"}, {"name": "result", "type": "dict", "fullType": "dict"}, {"name": "selfharm_eval", "type": "SelfHarmEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._self_harm.SelfHarmEvaluator"}, {"name": "sexual_eval", "type": "SexualEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._sexual.SexualEvaluator"}, {"name": "token", "type": "str", "fullType": "str"}, {"name": "token_provider", "type": "function", "fullType": "function"}, {"name": "violence_eval", "type": "ViolenceEvaluator", "fullType": "azure.ai.evaluation._evaluators._content_safety._violence.ViolenceEvaluator"}]

# %% [markdown]
# ## View the results in Azure AI Foundry
#
# Now that the evaluation is complete, you can navigate to the **Evaluation** section of the Azure AI Foundry portal to view the results. Alternatively, you can output a link to the evaluation location using the `studio_url` returned from running `evaluate`.

# %%
print(result['studio_url'])

# %% [markdown]
# ## Delete resources
#
# If you've finished exploring Azure AI Services, delete the Azure resource that you created during the workshop.
#
# **Note**: You may be prompted to delete your deployed model(s) before deleting the resource group.
